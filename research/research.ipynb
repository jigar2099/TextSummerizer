# %%
dict_info = {"key1":"value1", "key2":"value2","key3":"value3"}
dict_info["key1"]
# Out:
# 'value1'

# %%
dict_info.key
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 dict_info.key
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
from box import ConfigBox
dict_info = ConfigBox({"key1":"value1", "key2":"value2","key3":"value3"})
print(dict_info.key1, dict_info.key2)
# Out:
# value1 value2

# %%
def multiplication(x:int, y:int)->int:
    return (x*y)

# %%
multiplication(2,"4")
# Out:
# '44'

# %%
from ensure import ensure_annotations

@ensure_annotations
def multiplication(x:int, y:int)->int:
    return (x*y)

# %%
multiplication(2,4)
# Out:
# 8
